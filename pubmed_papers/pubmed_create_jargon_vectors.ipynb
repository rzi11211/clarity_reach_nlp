# %% [markdown]
# ### Get Count of Each Jargon Term in Each PubMed Document

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
jargon = pd.read_csv('../data/jargon.csv')
jargon.head()
# Out:
#            jargon_term
# 0          A/B testing
# 1             accuracy
# 2               action
# 3  activation function
# 4      active learning

# %%
pubmed = pd.read_csv('../data/pubmed_nltk_nostem_preproc_strings.csv').set_index('pmid')

# %%
pubmed.columns
# Out:
# Index(['date', 'citations', 'len_text', 'len_title', 'days_live', 'fulltext'], dtype='object')

# %%
pubmed.drop(columns=['date', 'len_text', 'len_title', 'days_live'], inplace=True)

# %%
# create a list to store the individual document dictionaries 
jargon_count_list = []

# iterate through each document
for document in pubmed['fulltext']:
    
    #create dictionary for each document to store the counts for each term
    doc_dict = {}

    #set up a counter variable to keep track of the total uses of all jargon terms
    total_jargon_count = 0  
    
    #iterate through the list of jargon terms
    for term in jargon['jargon_term']:
    
        #set up a counter for each individual jargon term 
        term_count = 0
        
        #count the number of times each indivivdual jargon term shows up in the document & store it 
        term_count = document.count(term)
        
        #store the term count in the individual document's dictionary
        doc_dict[term] = term_count
        
        #increment the total jargon count by this term's count
        total_jargon_count += term_count
        
        
    #add the document's total jargon count to the dictionary
    doc_dict['total_jargon_count'] = total_jargon_count
    
    #store the dictionary in the list 
    jargon_count_list.append(doc_dict)

# %%
results = pd.DataFrame(jargon_count_list)
results.index = pubmed.index
results
# Out:
#           A/B testing  accuracy  action  activation function  active learning  \
# pmid
# 22627698            0         0       1                    0                0
# 22952238            0         0       1                    0                0
# 22944687            0         1       1                    0                0
# 22075226            0         0       0                    0                0
# 23012584            0         0       0                    0                0
# ...               ...       ...     ...                  ...              ...
# 33392139            0         0       0                    0                0
# 33375609            0         0       0                    0                0
# 32378163            0         0       0                    0                0
# 33307272            0         0       0                    0                0
# 33291844            0         0       0                    0                0
#
#           AdaGrad  agent  agglomerative clustering  AR  \
# pmid
# 22627698        0      0                         0   0
# 22952238        0      0                         0   0
# 22944687        0      0                         0   0
# 22075226        0      0                         0   0
# 23012584        0      0                         0   0
# ...           ...    ...                       ...  ..
# 33392139        0      0                         0   0
# 33375609        0      0                         0   0
# 32378163        0      0                         0   0
# 33307272        0      0                         0   0
# 33291844        0      0                         0   0
#
#           area under the PR curve  ...  user matrix  validation  \
# pmid                               ...
# 22627698                        0  ...            0           1
# 22952238                        0  ...            0           0
# 22944687                        0  ...            0           0
# 22075226                        0  ...            0           0
# 23012584                        0  ...            0           0
# ...                           ...  ...          ...         ...
# 33392139                        0  ...            0           0
# 33375609                        0  ...            0           0
# 32378163                        0  ...            0           0
# 33307272                        0  ...            0           0
# 33291844                        0  ...            0           0
#
#           validation set  vanishing gradient problem  Wasserstein loss  \
# pmid
# 22627698               0                           0                 0
# 22952238               0                           0                 0
# 22944687               0                           0                 0
# 22075226               0                           0                 0
# 23012584               0                           0                 0
# ...                  ...                         ...               ...
# 33392139               0                           0                 0
# 33375609               0                           0                 0
# 32378163               0                           0                 0
# 33307272               0                           0                 0
# 33291844               0                           0                 0
#
#           weight  Weighted Alternating Least Squares (WALS)  wide model  \
# pmid
# 22627698       0                                          0           0
# 22952238       0                                          0           0
# 22944687       0                                          0           0
# 22075226       0                                          0           0
# 23012584       0                                          0           0
# ...          ...                                        ...         ...
# 33392139       0                                          0           0
# 33375609       0                                          0           0
# 32378163       0                                          0           0
# 33307272       0                                          0           0
# 33291844       0                                          0           0
#
#           width  total_jargon_count
# pmid
# 22627698      0                  11
# 22952238      0                   3
# 22944687      0                   7
# 22075226      0                   2
# 23012584      0                   1
# ...         ...                 ...
# 33392139      0                   3
# 33375609      0                   5
# 32378163      0                   3
# 33307272      0                   2
# 33291844      0                   3
#
# [2809 rows x 413 columns]

# %%
df = pd.concat([pubmed, results], axis=1)

# %%
df.head(20)
# Out:
#           citations                                           fulltext  \
# pmid
# 22627698         35  extracting biological information computationa...
# 22952238          4  uncovering transcription factor modules using ...
# 22944687         19  understanding substrate specificity convention...
# 22075226         12  membrane protein structural bioinformatics des...
# 23012584         10  future medical diagnostics: large digitized da...
# 22528508         20  paradigm shift toxicity testing modeling limit...
# 22366294         51  evaluating state art coreference resolution el...
# 22752090         31  risk estimation risk prediction using machinel...
# 22776068          8  predicting risk psychosis onset: advances pros...
# 22842200         42  osteoarthritis year 2012 review: biomarkers pu...
# 22695048         39  hierarchical reinforcement learning decision m...
# 23335577          7  human semisupervised learning empirical work h...
# 23071097         17  popular computational methods assess multiprot...
# 22784485         74  distinguishing unipolar depression bipolar dep...
# 23382431         68  global mapping infectious disease primary aim ...
# 22611119         26  machine learning approaches discovery genegene...
# 23392334          3  bridging paradigms: hybrid mechanisticdiscrimi...
# 23349097          8  toward "structural blast": using structural re...
# 23637855         14  plea neutral comparison studies computational ...
# 23622061         38  decision making: neuroscience psychiatry adapt...
#
#           A/B testing  accuracy  action  activation function  active learning  \
# pmid
# 22627698            0         0       1                    0                0
# 22952238            0         0       1                    0                0
# 22944687            0         1       1                    0                0
# 22075226            0         0       0                    0                0
# 23012584            0         0       0                    0                0
# 22528508            0         0       1                    0                0
# 22366294            0         0       0                    0                0
# 22752090            0         0       0                    0                0
# 22776068            0         1       0                    0                0
# 22842200            0         0       0                    0                0
# 22695048            0         0       0                    0                0
# 23335577            0         0       0                    0                0
# 23071097            0         1       8                    0                0
# 22784485            0         1       1                    0                0
# 23382431            0         0       0                    0                0
# 22611119            0         0       3                    0                0
# 23392334            0         0       0                    0                0
# 23349097            0         1       3                    0                0
# 23637855            0         0       0                    0                0
# 23622061            0         0       0                    0                0
#
#           AdaGrad  agent  agglomerative clustering  ...  user matrix  \
# pmid                                                ...
# 22627698        0      0                         0  ...            0
# 22952238        0      0                         0  ...            0
# 22944687        0      0                         0  ...            0
# 22075226        0      0                         0  ...            0
# 23012584        0      0                         0  ...            0
# 22528508        0      0                         0  ...            0
# 22366294        0      0                         0  ...            0
# 22752090        0      0                         0  ...            0
# 22776068        0      0                         0  ...            0
# 22842200        0      0                         0  ...            0
# 22695048        0      0                         0  ...            0
# 23335577        0      0                         0  ...            0
# 23071097        0      0                         0  ...            0
# 22784485        0      0                         0  ...            0
# 23382431        0      0                         0  ...            0
# 22611119        0      0                         0  ...            0
# 23392334        0      0                         0  ...            0
# 23349097        0      0                         0  ...            0
# 23637855        0      0                         0  ...            0
# 23622061        0      0                         0  ...            0
#
#           validation  validation set  vanishing gradient problem  \
# pmid
# 22627698           1               0                           0
# 22952238           0               0                           0
# 22944687           0               0                           0
# 22075226           0               0                           0
# 23012584           0               0                           0
# 22528508           0               0                           0
# 22366294           0               0                           0
# 22752090           0               0                           0
# 22776068           0               0                           0
# 22842200           0               0                           0
# 22695048           0               0                           0
# 23335577           0               0                           0
# 23071097           0               0                           0
# 22784485           0               0                           0
# 23382431           0               0                           0
# 22611119           0               0                           0
# 23392334           0               0                           0
# 23349097           0               0                           0
# 23637855           0               0                           0
# 23622061           0               0                           0
#
#           Wasserstein loss  weight  Weighted Alternating Least Squares (WALS)  \
# pmid
# 22627698                 0       0                                          0
# 22952238                 0       0                                          0
# 22944687                 0       0                                          0
# 22075226                 0       0                                          0
# 23012584                 0       0                                          0
# 22528508                 0       0                                          0
# 22366294                 0       0                                          0
# 22752090                 0       0                                          0
# 22776068                 0       0                                          0
# 22842200                 0       0                                          0
# 22695048                 0       0                                          0
# 23335577                 0       0                                          0
# 23071097                 0       0                                          0
# 22784485                 0       0                                          0
# 23382431                 0       0                                          0
# 22611119                 0       0                                          0
# 23392334                 0       0                                          0
# 23349097                 0       0                                          0
# 23637855                 0       0                                          0
# 23622061                 0       0                                          0
#
#           wide model  width  total_jargon_count
# pmid
# 22627698           0      0                  11
# 22952238           0      0                   3
# 22944687           0      0                   7
# 22075226           0      0                   2
# 23012584           0      0                   1
# 22528508           0      0                  11
# 22366294           0      0                   4
# 22752090           0      0                   4
# 22776068           0      0                  12
# 22842200           0      0                   3
# 22695048           0      0                   2
# 23335577           0      0                  15
# 23071097           0      0                  17
# 22784485           0      0                   6
# 23382431           0      0                   5
# 22611119           0      0                   6
# 23392334           0      0                   4
# 23349097           0      0                  11
# 23637855           0      0                   4
# 23622061           0      0                   3
#
# [20 rows x 415 columns]

# %%
df['citations'].corr(df['total_jargon_count'])
# Out:
# 0.02749869277836604

# %% [markdown]
# Once again there doesn't appear to be much of a relationship between the number of citations and the total jargon count.

# %%
plt.hist(df['total_jargon_count'], bins = 100);

# %% [markdown]
# The total jargon count has a nice normal-looking distribution.

# %%
#save vectorized data 
df.to_csv('../data/pubmed_vectorized_jargon.csv')

# %%
df.sum()
# Out:
# citations                                                                                24417
# fulltext                                     extracting biological information computationa...
# A/B testing                                                                                  0
# accuracy                                                                                   478
# action                                                                                    1018
#                                                                    ...
# weight                                                                                      43
# Weighted Alternating Least Squares (WALS)                                                    0
# wide model                                                                                   0
# width                                                                                        7
# total_jargon_count                                                                       22189
# Length: 415, dtype: object
