# %% [markdown]
# # PubMed Papers: Get Abstracts
# #### *Use pmidcite, requests, and BeautifulSoup to scrape posts from TowardsDataScience.com*

# %% [markdown]
# ### *Query PubMed IDs using pmidcite and scrape NIH site for abstracts and citations

# %%
# Import libaries

import pandas as pd
import requests 
import numpy as np
from time import sleep 
from pmidcite.cfg import Cfg
from pmidcite.eutils.cmds.pubmed import PubMed

from bs4 import BeautifulSoup

# %%
cfg = Cfg(prt_fullname=False)
# Out:
#   READ: .pmidciterc

# %% [markdown]
# ## Instantiate a PubMed object

# %%
pmobj = PubMed(
    email=cfg.get_email(),
    apikey=cfg.get_apikey(),
    tool=cfg.get_tool())

# %% [markdown]
# ## Query PubMed, download PMIDs

# %%
pubmed_query = '("machine learning"[Title/Abstract]) AND ((fha[Filter]) AND (classicalarticle[Filter] OR journalarticle[Filter] OR meta-analysis[Filter] OR review[Filter] OR systematicreview[Filter] OR technicalreport[Filter]) AND (2010/1/1:2020/12/31[pdat]) AND (english[Filter]))'
pmids = pmobj.dnld_query_pmids(pubmed_query)
# Out:
#  3,152 IDs FOR pubmed QUERY(("machine learning"[Title/Abstract]) AND ((fha[Filter]) AND (classicalarticle[Filter] OR journalarticle[Filter] OR meta-analysis[Filter] OR review[Filter] OR systematicreview[Filter] OR technicalreport[Filter]) AND (2010/1/1:2020/12/31[pdat]) AND (english[Filter])))

# %%
pmid_df = pd.DataFrame(pmids, columns = ['pmid'])

# %%
pmid_df.to_csv('../capstone_project/data/list_of_pmids.csv',index=False)

# %% [markdown]
# ### Scrape info from NIH Site

# %%
#test url
url = 'https://pubmed.ncbi.nlm.nih.gov/31058383/'

#check status
res = requests.get(url)
res
# Out:
# <Response [200]>

# %%
page = requests.get(url)
soup = BeautifulSoup(page.text,'html.parser')

# %%
pmid_df = pd.read_csv('../data/list_of_pmids.csv')

# %%
abstract_list = []

batch = 1
counter = 1

for pmid in pmid_df['pmid']:
    abstract_dict = {}
    url = (f'https://pubmed.ncbi.nlm.nih.gov/{pmid}/')
    page  = requests.get(url)
    soup = BeautifulSoup(page.text, 'html.parser')

    #store pmid
    abstract_dict['pmid'] = pmid

    #get number of citations
    for row in soup.find_all('h2', {'class' : 'title'}):
        try: 
            abstract_dict['citations'] = int((row.find('em', {'class' : 'amount'}).text))
        except:
            pass

    #get abstract title
    try:
        abstract_dict['title'] = soup.find('h1').text.strip('\n \n \n \n \n \n \n')
    except:
        pass

    #get paper date
    try:
        abstract_dict['date'] = soup.find('span', {'class' : 'cit'}).text
    except:
        pass

    #get abstract text
    try:
        abstract_dict['text'] = soup.find('div', {'class' : 'abstract-content selected'}).text.replace('\n','').strip()
    except:
         pass
        
    counter +=1

    abstract_list.append(abstract_dict)
    sleep(np.random.randint(1, 5))
    
    if (counter % 100 == 0) or (counter == len(pmid_df['pmid'])):
        print('save here')
        df = pd.DataFrame(abstract_list)
        df.to_csv(f'data/raw_pubmed/{batch}_abstracts.csv',index=False)
        abstract_list = []
        batch +=1
    else: 
        pass
# Out:
# save here
# save here
# save here
# save here
# save here
# save here
# save here
# save here
# save here
# save here
# save here
# save here
# save here
# save here
# save here
# save here
# save here
# save here
# save here
# save here
# save here
# save here
# save here
# save here
# save here
# save here
# save here
# save here
# save here
# save here
# save here
# save here

# %%
df
# Out:
#         pmid  citations                                              title  \
# 0   21924741       29.0  Methods and tools for objective assessment of ...
# 1   21911058       27.0  Spelling with non-invasive Brain-Computer Inte...
# 2   21864218        5.0  Computational modeling of P450s for toxicity p...
# 3   21863503        1.0  Representation, simulation, and hypothesis gen...
# 4   21846786      161.0       Natural language processing: an introduction
# 5   21795890       22.0  Use of advanced machine-learning techniques fo...
# 6   21787301        4.0  Machine learning algorithms for predicting pro...
# 7   21787299        8.0  Structural protein descriptors in 1-dimension ...
# 8   21787298        2.0  Cellular automata and its applications in prot...
# 9   21780006        2.0  In silico prediction of post-translational mod...
# 10  21721140       12.0  Informatics and standards for nanomedicine tec...
# 11  21707399       13.0  Computational tools for polypharmacology and r...
# 12  21607908        3.0  Advanced technology development for remote tri...
# 13  21470173        1.0  Present perspectives on the automated classifi...
# 14  21470169        2.0  Quantitative chemogenomics: machine-learning m...
# 15  21466461        2.0  From data processing to multivariate validatio...
# 16  21464505       31.0  Parameter estimation using meta-heuristics in ...
# 17  21452981        4.0  Informatics, machine learning and computationa...
# 18  21431559       19.0  Decision tree and ensemble learning algorithms...
# 19  21393536      203.0  How to grow a mind: statistics, structure, and...
# 20  21303343       13.0  Development of anti-viral agents using molecul...
# 21  21269608       26.0  A tutorial introduction to Bayesian models of ...
# 22  27467875       13.0  Chemoinformatics as a Theoretical Chemistry Di...
# 23  22889876       55.0     Random forests for genetic association studies
# 24  21172442      140.0  Introduction to machine learning for brain ima...
# 25  21039646      157.0      Supervised classification of human microbiota
# 26  25076977       46.0  Mapping Mental Function to Brain Structure: Ho...
# 27  21029850       23.0  Detecting, characterizing, and interpreting no...
# 28  21029849       16.0  Multigenic modeling of complex disease by rand...
# 29  20887262        1.0  Detecting atypical examples of known domain ty...
# 30  20887261       12.0  Topology prediction of helical transmembrane p...
# 31  20838967       36.0  Similarity searching using 2D structural finge...
# 32  20810180       25.0  Neuroimaging-based approaches in the brain-com...
# 33  20801638       51.0  Machines that learn to segment images: a cruci...
# 34  20699326       11.0  Evidence for CRHR1 in multiple sclerosis using...
# 35  20678228       71.0  Automatic de-identification of textual documen...
# 36  20647054       34.0  Natural Language Processing methods and system...
# 37  20644953       57.0  What do the basal ganglia do? A modeling persp...
# 38  20617142        5.0  Comparative pathogenesis and systems biology f...
# 39  20596934        NaN                Computational neuroscience in China
# 40  20500882        8.0  Semantic annotation of morphological descripti...
# 41  20491597       16.0  Integrated diagnostics: a conceptual framework...
# 42  20488979       33.0  Automated image analysis for high-content scre...
# 43  20465523        2.0  Machine learning algorithms for the prediction...
# 44  20453924       14.0  New insights into the biogenesis of nuclear RN...
# 45  20381467        6.0  Computational methodologies for studying non-c...
# 46  20221928       14.0             Protein secondary structure prediction
# 47  20131763       18.0  Potential energy surfaces fitted by artificial...
# 48  20064794        4.0  Use of statistical analysis in the biomedical ...
# 49  21713313        8.0  Computational intelligence in early diabetes d...
# 50  20008395        8.0                 Learning to represent visual input
# 51  19969101       50.0  Rationalizing the chemical space of protein-pr...
#
#                               date  \
# 0          2011 Nov;171(1):e81-95.
# 1    Jan-Jun 2011;105(1-3):106-14.
# 2          2011 Oct;7(10):1211-31.
# 3                 2011;759:465-82.
# 4       Sep-Oct 2011;18(5):544-51.
# 5     2011 Jul;71(1 Suppl):S25-32.
# 6          2011 Sep;12(6):490-502.
# 7           2011 Sep;12(6):470-89.
# 8           2011 Sep;12(6):508-19.
# 9                 2011;760:325-40.
# 10      Sep-Oct 2011;3(5):511-532.
# 11            2011 Jun;3(8):961-8.
# 12             Apr-Jun 2011;61-72.
# 13          2011;11(15):1994-2009.
# 14            2011;11(15):1978-93.
# 15        2011 Jul;12(7):996-1004.
# 16      Jan-Feb 2012;9(1):185-202.
# 17           2011 Mar;3(4):451-67.
# 18                 2011;696:191-9.
# 19  2011 Mar 11;331(6022):1279-85.
# 20           2011 Feb;11(1):64-93.
# 21         2011 Sep;120(3):302-21.
# 22        2011 Jan 17;30(1):20-32.
# 23                  2011;10(1):32.
# 24       2011 May 15;56(2):387-99.
# 25          2011 Mar;35(2):343-59.
# 26           2010 Nov;5(6):753-61.
# 27                 2010;72:101-16.
# 28                  2010;72:73-99.
# 29          2010 Nov;11(7):538-49.
# 30          2010 Nov;11(7):550-61.
# 31                2011;672:133-58.
# 32         2010 Nov;28(11):552-60.
# 33          2010 Oct;20(5):653-66.
# 34      2010 Nov 1;19(21):4286-95.
# 35               2010 Aug 2;10:70.
# 36          2011 Feb;44(1):163-79.
# 37         2010 Sep;103(3):237-53.
# 38               2010;2010:236528.
# 39         2010 Mar;53(3):385-397.
# 40             2010 May 25;11:278.
# 41          2010 Jul;48(7):989-98.
# 42          2010 Aug;15(7):726-34.
# 43           2010 Jul;6(7):821-33.
# 44          2010 Apr;88(2):211-21.
# 45        2010 Jun 18;1338:131-45.
# 46                2010;609:327-48.
# 47    2010 Mar 18;114(10):3371-83.
# 48         Jan-Feb 2010;17(1):3-5.
# 49        Winter 2010;7(4):252-62.
# 50   2010 Jan 12;365(1537):177-84.
# 51         2010 Mar;15(5-6):220-9.
#
#                                                  text
# 0   Training and assessment paradigms for laparosc...
# 1   Brain-Computer Interfaces (BCIs) have become a...
# 2   Introduction:                    Drug developm...
# 3   This chapter presents a discussion of metaboli...
# 4   Objectives:                    To provide an o...
# 5   Background:                    Hemorrhagic sho...
# 6   Machine learning algorithms have wide range of...
# 7   The last few decades observed an increasing in...
# 8   With the explosion of protein sequences genera...
# 9   Methods for predicting protein post-translatio...
# 10  There are several issues to be addressed conce...
# 11  Most drugs act on a multitude of targets rathe...
# 12  Combat developers within the Army have envisio...
# 13  The G-protein coupled receptors--or GPCRs--com...
# 14  Chemogenomics is an emerging interdisciplinary...
# 15  In metabolomics studies there is a clear incre...
# 16  This paper gives a comprehensive review of the...
# 17  This article reviews the use of informatics an...
# 18  Machine learning approaches have wide applicat...
# 19  In coming to understand the world-in learning ...
# 20  Computational chemistry has always played a ke...
# 21  We present an introduction to Bayesian inferen...
# 22  Here, chemoinformatics is considered as a theo...
# 23  The Random Forests (RF) algorithm has become a...
# 24  Machine learning and pattern recognition algor...
# 25  Recent advances in DNA sequencing technology h...
# 26  The goal of cognitive neuroscience is to ident...
# 27  Human health is a complex process that is depe...
# 28  The genetics and heredity of complex human tra...
# 29  SBASE is a project initiated to detect known d...
# 30  Transmembrane protein topology prediction meth...
# 31  This chapter reviews the use of molecular fing...
# 32  Techniques to enable direct communication betw...
# 33  Connections between neurons can be found by ch...
# 34  The primary genetic risk factor in multiple sc...
# 35  Background:                    In the United S...
# 36  While the biomedical informatics community wid...
# 37  Basal ganglia (BG) constitute a network of sev...
# 38  Developing vaccines to biothreat agents presen...
# 39  The ultimate goal of Computational Neuroscienc...
# 40  Background:                    Large volumes o...
# 41  With the advent of digital pathology, imaging ...
# 42  The field of high-content screening and analys...
# 43  Importance of the field:                    Th...
# 44  More than 30 years of research on nuclear RNA ...
# 45  Non-coding RNAs (ncRNAs) are a large and diver...
# 46  While the prediction of a native protein struc...
# 47  Molecular mechanics is the tool of choice for ...
# 48  Statistics is an essential aspect of biomedica...
# 49  The development of an effective diabetes diagn...
# 50  One of the central problems in computational n...
# 51  Protein-protein interactions (PPIs) are one of...
