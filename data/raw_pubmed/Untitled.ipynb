# %%
import numpy as np
import pandas as pd

pd.read_csv('17_abstracts.csv').head(10)
# Out:
#        pmid  citations                                              title  \
# 0  31229078        6.0  Alternative data mining/machine learning metho...
# 1  31226833        2.0  Is It Possible to Predict the Odor of a Molecu...
# 2  31222562        3.0  Overview of image-to-image translation by use ...
# 3  31222375        6.0  Machine learning approaches for pathologic dia...
# 4  31221831        9.0        Trends and challenges in robot manipulation
# 5  31220370        2.0  Machine learning and statistical models for pr...
# 6  31219658        8.0  Current status of artificial intelligence appl...
# 7  31217702        6.0                       Critical Care, Critical Data
# 8  31215361        1.0  Recent Advances in Machine Learning Based Pred...
# 9  31214847        6.0  Structural Imaging in Parkinson's Disease: New...
#
#                                date  \
# 0               2019 Aug;122:25-39.
# 1          2019 Jun 20;20(12):3018.
# 2           2019 Sep;12(3):235-248.
# ...
